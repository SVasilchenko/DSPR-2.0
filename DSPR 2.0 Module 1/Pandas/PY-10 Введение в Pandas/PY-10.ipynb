# %%
import pandas as pd

countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index=False, sep=';')

# %%
df = pd.read_csv('data\melb_data.csv')
df.head(16)
# Out:
#     index      Suburb              Address  Rooms Type      Price Method  \
# 0       0  Abbotsford         85 Turner St      2    h  1480000.0      S
# 1       1  Abbotsford      25 Bloomburg St      2    h  1035000.0      S
# 2       2  Abbotsford         5 Charles St      3    h  1465000.0     SP
# 3       3  Abbotsford     40 Federation La      3    h   850000.0     PI
# 4       4  Abbotsford          55a Park St      4    h  1600000.0     VB
# 5       5  Abbotsford       129 Charles St      2    h   941000.0      S
# 6       6  Abbotsford         124 Yarra St      3    h  1876000.0      S
# 7       7  Abbotsford        98 Charles St      2    h  1636000.0      S
# 8       8  Abbotsford   6/241 Nicholson St      1    u   300000.0      S
# 9       9  Abbotsford        10 Valiant St      2    h  1097000.0      S
# 10     10  Abbotsford   411/8 Grosvenor St      2    u   700000.0     VB
# 11     11  Abbotsford      40 Nicholson St      3    h  1350000.0     VB
# 12     12  Abbotsford  123/56 Nicholson St      2    u   750000.0      S
# 13     13  Abbotsford        45 William St      2    h  1172500.0      S
# 14     14  Abbotsford   7/20 Abbotsford St      1    u   441000.0     SP
# 15     15  Abbotsford        16 William St      2    h  1310000.0      S
#
#    SellerG        Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0   Biggin   3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1   Biggin   4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2   Biggin   4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3   Biggin   4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4   Nelson   4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
# 5   Jellis   7/05/2016       2.5  ...  0.0     181.0         126.0     1970.0
# 6   Nelson   7/05/2016       2.5  ...  0.0     245.0         210.0     1910.0
# 7   Nelson   8/10/2016       2.5  ...  2.0     256.0         107.0     1890.0
# 8   Biggin   8/10/2016       2.5  ...  1.0       0.0         126.0     1970.0
# 9   Biggin   8/10/2016       2.5  ...  2.0     220.0          75.0     1900.0
# 10  Jellis  12/11/2016       2.5  ...  1.0       0.0         126.0     1970.0
# 11  Nelson  12/11/2016       2.5  ...  2.0     214.0         190.0     2005.0
# 12  Biggin  12/11/2016       2.5  ...  1.0       0.0          94.0     2009.0
# 13  Biggin  13/08/2016       2.5  ...  1.0     195.0         126.0     1970.0
# 14    Greg  14/05/2016       2.5  ...  1.0       0.0         126.0     1970.0
# 15  Jellis  15/10/2016       2.5  ...  2.0     238.0          97.0     1890.0
#
#     CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# 0         Yarra   -37.7996    144.9984  Northern Metropolitan         4019.0
# 1         Yarra   -37.8079    144.9934  Northern Metropolitan         4019.0
# 2         Yarra   -37.8093    144.9944  Northern Metropolitan         4019.0
# 3         Yarra   -37.7969    144.9969  Northern Metropolitan         4019.0
# 4         Yarra   -37.8072    144.9941  Northern Metropolitan         4019.0
# 5         Yarra   -37.8041    144.9953  Northern Metropolitan         4019.0
# 6         Yarra   -37.8024    144.9993  Northern Metropolitan         4019.0
# 7         Yarra   -37.8060    144.9954  Northern Metropolitan         4019.0
# 8         Yarra   -37.8008    144.9973  Northern Metropolitan         4019.0
# 9         Yarra   -37.8010    144.9989  Northern Metropolitan         4019.0
# 10        Yarra   -37.8110    145.0067  Northern Metropolitan         4019.0
# 11        Yarra   -37.8085    144.9964  Northern Metropolitan         4019.0
# 12        Yarra   -37.8078    144.9965  Northern Metropolitan         4019.0
# 13        Yarra   -37.8084    144.9973  Northern Metropolitan         4019.0
# 14        Yarra   -37.8016    144.9988  Northern Metropolitan         4019.0
# 15        Yarra   -37.8090    144.9976  Northern Metropolitan         4019.0
#
#            Coordinates
# 0   -37.7996, 144.9984
# 1   -37.8079, 144.9934
# 2   -37.8093, 144.9944
# 3   -37.7969, 144.9969
# 4   -37.8072, 144.9941
# 5   -37.8041, 144.9953
# 6   -37.8024, 144.9993
# 7    -37.806, 144.9954
# 8   -37.8008, 144.9973
# 9    -37.801, 144.9989
# 10   -37.811, 145.0067
# 11  -37.8085, 144.9964
# 12  -37.8078, 144.9965
# 13  -37.8084, 144.9973
# 14  -37.8016, 144.9988
# 15   -37.809, 144.9976
#
# [16 rows x 23 columns]

# %%
df.loc[15]['Price']
# Out:
# 1310000.0

# %%
df.loc[90, 'Date']
# Out:
# '10/09/2016'

# %%
df.loc[3521, 'Landsize']/df.loc[1690, 'Landsize']
# Out:
# 2.7857142857142856

# %%
df.tail(7)
df.shape
# Out:
# (13580, 23)

# %%
df.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# std        0.965921      0.691712      0.960793    3990.669241    392.217403
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%        2.000000      1.000000      1.000000     177.000000    122.000000
# 50%        3.000000      1.000000      2.000000     440.000000    126.000000
# 75%        3.000000      2.000000      2.000000     651.000000    129.940000
# max       20.000000      8.000000     10.000000  433014.000000  44515.000000
#
#           YearBuilt     Lattitude    Longtitude  Propertycount
# count  13580.000000  13580.000000  13580.000000   13580.000000
# mean    1966.788218    -37.809203    144.995216    7454.417378
# std       29.088642      0.079260      0.103916    4378.581772
# min     1196.000000    -38.182550    144.431810     249.000000
# 25%     1960.000000    -37.856822    144.929600    4380.000000
# 50%     1970.000000    -37.802355    145.000100    6555.000000
# 75%     1975.000000    -37.756400    145.058305   10331.000000
# max     2018.000000    -37.408530    145.526350   21650.000000

# %%
df['Car'] = df['Car'].astype('int64')
df['Bedroom'] = df['Bedroom'].astype('int64')
df['Bathroom'] = df['Bathroom'].astype('int64')
df['Propertycount'] = df['Propertycount'].astype('int64')
df['YearBuilt'] = df['YearBuilt'].astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
#  17  CouncilArea    12211 non-null  object
#  18  Lattitude      13580 non-null  float64
#  19  Longtitude     13580 non-null  float64
#  20  Regionname     13580 non-null  object
#  21  Propertycount  13580 non-null  int64
#  22  Coordinates    13580 non-null  object
# dtypes: float64(6), int64(8), object(9)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# std        0.965921      0.691712      0.960793    3990.669241    392.217403
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%        2.000000      1.000000      1.000000     177.000000    122.000000
# 50%        3.000000      1.000000      2.000000     440.000000    126.000000
# 75%        3.000000      2.000000      2.000000     651.000000    129.940000
# max       20.000000      8.000000     10.000000  433014.000000  44515.000000
#
#           YearBuilt     Lattitude    Longtitude  Propertycount
# count  13580.000000  13580.000000  13580.000000   13580.000000
# mean    1966.788218    -37.809203    144.995216    7454.417378
# std       29.088642      0.079260      0.103916    4378.581772
# min     1196.000000    -38.182550    144.431810     249.000000
# 25%     1960.000000    -37.856822    144.929600    4380.000000
# 50%     1970.000000    -37.802355    145.000100    6555.000000
# 75%     1975.000000    -37.756400    145.058305   10331.000000
# max     2018.000000    -37.408530    145.526350   21650.000000

# %%
df['Suburb'].describe(include=object)
# Out:
# count         13580
# unique          314
# top       Reservoir
# freq            359
# Name: Suburb, dtype: object

# %%
df['Suburb'].value_counts()
# Out:
# Suburb
# Reservoir         359
# Richmond          260
# Bentleigh East    249
# Preston           239
# Brunswick         222
#                  ...
# Sandhurst           1
# Bullengarook        1
# Croydon South       1
# Montrose            1
# Monbulk             1
# Name: count, Length: 314, dtype: int64

# %%
df['Regionname'].value_counts(normalize=True)
# Out:
# Regionname
# Southern Metropolitan         0.345729
# Northern Metropolitan         0.286451
# Western Metropolitan          0.217084
# Eastern Metropolitan          0.108321
# South-Eastern Metropolitan    0.033137
# Eastern Victoria              0.003903
# Northern Victoria             0.003019
# Western Victoria              0.002356
# Name: proportion, dtype: float64

# %%
import numpy as np
from collections import Counter

c = Counter(list(df['CouncilArea']))
c[np.nan]
# Out:
# 1369

# %%
df['CouncilArea'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 13580 entries, 0 to 13579
# Series name: CouncilArea
# Non-Null Count  Dtype
# --------------  -----
# 12211 non-null  object
# dtypes: object(1)
# memory usage: 106.2+ KB

# %%
df['Type'].value_counts(normalize=True)
# Out:
# Type
# h    0.695803
# u    0.222165
# t    0.082032
# Name: proportion, dtype: float64

# %%
import pandas as pd

# %%
a = 3.14
print(a.as_integer_ratio())
# Out:
# (7070651414971679, 2251799813685248)
